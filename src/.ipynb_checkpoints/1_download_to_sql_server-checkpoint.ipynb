# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Fill-Tables-with-data-from-jsons" data-toc-modified-id="Fill-Tables-with-data-from-jsons-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Fill Tables with data from jsons</a></span><ul class="toc-item"><li><span><a href="#regattas" data-toc-modified-id="regattas-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>regattas</a></span></li><li><span><a href="#races" data-toc-modified-id="races-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>races</a></span></li><li><span><a href="#competitors" data-toc-modified-id="competitors-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>competitors</a></span></li><li><span><a href="#windsources-&amp;-wind" data-toc-modified-id="windsources-&amp;-wind-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>windsources &amp; wind</a></span></li><li><span><a href="#legs" data-toc-modified-id="legs-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>legs</a></span></li><li><span><a href="#race_comp" data-toc-modified-id="race_comp-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>race_comp</a></span></li><li><span><a href="#comp_leg" data-toc-modified-id="comp_leg-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>comp_leg</a></span></li><li><span><a href="#positions" data-toc-modified-id="positions-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>positions</a></span></li><li><span><a href="#courses" data-toc-modified-id="courses-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>courses</a></span></li><li><span><a href="#marks" data-toc-modified-id="marks-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>marks</a></span></li><li><span><a href="#marks_positions" data-toc-modified-id="marks_positions-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>marks_positions</a></span></li><li><span><a href="#Extra-functions-in-case-something-went-wrong-for-a-few-entries" data-toc-modified-id="Extra-functions-in-case-something-went-wrong-for-a-few-entries-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Extra functions in case something went wrong for a few entries</a></span></li></ul></li><li><span><a href="#Fill-columns-with-extra-information-to-complete-database" data-toc-modified-id="Fill-columns-with-extra-information-to-complete-database-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Fill columns with extra information to complete database</a></span><ul class="toc-item"><li><span><a href="#Update-final-rank-in-race_comp" data-toc-modified-id="Update-final-rank-in-race_comp-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Update final rank in race_comp</a></span></li><li><span><a href="#Get-chosen-side-of-competitors-for-leg-1" data-toc-modified-id="Get-chosen-side-of-competitors-for-leg-1-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Get chosen side of competitors for leg 1</a></span></li><li><span><a href="#Determining-Course-Area" data-toc-modified-id="Determining-Course-Area-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Determining Course Area</a></span></li><li><span><a href="#Number-of-competitors-per-race-and-their-relative-rank" data-toc-modified-id="Number-of-competitors-per-race-and-their-relative-rank-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Number of competitors per race and their relative rank</a></span></li><li><span><a href="#Categorize-Sailing-Style-per-Race" data-toc-modified-id="Categorize-Sailing-Style-per-Race-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Categorize Sailing Style per Race</a></span></li><li><span><a href="#Positions-Start-Line" data-toc-modified-id="Positions-Start-Line-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Positions Start Line</a></span></li><li><span><a href="#positions_view" data-toc-modified-id="positions_view-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>positions_view</a></span></li><li><span><a href="#Calculate-Correlations" data-toc-modified-id="Calculate-Correlations-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Calculate Correlations</a></span></li></ul></li><li><span><a href="#Extra" data-toc-modified-id="Extra-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Extra</a></span><ul class="toc-item"><li><span><a href="#Usefull-other-queries" data-toc-modified-id="Usefull-other-queries-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Usefull other queries</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Fill Tables with data from jsons

# %%
###############################
## Tabellen vullen
###############################
import os, sys, inspect, json
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
from lib.Utilities.globalVar import *
import lib.TransformData.combineData as combd
import Download.download as download
from Utilities.converter import *

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
from sqlalchemy import *
from sqlalchemy.exc import IntegrityError, InternalError
from sqlalchemy.types import BINARY, VARCHAR
import pandas as pd
import numpy as np
from math import *
import urllib, json, requests


import pyodbc


from sqlalchemy.types import TypeDecorator, CHAR
from sqlalchemy.dialects.postgresql import UUID
import uuid

# %%
server = 'sic-match-analysis.database.windows.net'
database = 'match-analysis'
username = 'sic-admin'
password = 'ZeilenIsLeuk!'
driver= '{ODBC Driver 17 for SQL Server}'
connection_str = 'DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password


cnxn = pyodbc.connect(connection_str)
cursor = cnxn.cursor()

quoted = urllib.parse.quote_plus(connection_str)
engine = create_engine('mssql+pyodbc:///?odbc_connect={}'.format(quoted))

from sqlalchemy import event

@event.listens_for(engine, 'before_cursor_execute')
def receive_before_cursor_execute(conn, cursor, statement, params, context, executemany):
    if executemany:
        cursor.fast_executemany = True
        cursor.commit()

# %%
## Lukt niet om met bulk insert vanaf locale dir bestanden up te loaden :( dus moet via pandas to_sql
# cursor.execute("""
# BULK INSERT regattas
# FROM '\\usman-ess/Folder Redirection/Nerine/Documents/TU_Delft/2_Master/3_Stage/2_Code/SAPDataAnalysis/data/raw/tokyo2019'
# """)
event  = [{'name' :  'hwcs2020-round1', 'AllRegattas': True, 'regattaNameContaining': '', 'raceNameContaining': ''}
         ,{'name' : 'www', 'AllRegattas' : False, 'regattaNameContaining': 'Enoshima', 'raceNameContaining': ''}
         ,{'name' :  'tokyo2019', 'AllRegattas': True, 'regattaNameContaining': '', 'raceNameContaining': ''}]
events = [{'name' :  'tokyo2019', 'AllRegattas': True, 'regattaNameContaining': '', 'raceNameContaining': ''}]
eventSelection = events
parentdir
cd = combd.combineData()

# %% [markdown]
# ## regattas

# %%
## TABLE 1 regattas
for serv in eventSelection:
    filepath = parentdir + '/' +  outdirbase + serv['name'] + '/regattas'
    with open(filepath + '.json') as json_file:
        print('file extracted: ', filepath)
        data = json.load(json_file)
    cd = combd.combineData(serv)
    df = cd.transformJsonToPD(data, 'regattas')
    serv['regattas'] = df
    try:
        df.to_sql('regattas', con = engine, index = False, if_exists = 'append')
        print('Succesfully added regattas of {} to the database'.format(serv['name']))
    except IntegrityError as e:
        print('Could not add regattas of {} to the database because of IntegrityError: {}'.format(serv['name'], e))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-916bc6c3a152> in <module>
#       1 ## TABLE 1 regattas
#       2 for serv in eventSelection:
# ----> 3     filepath = parentdir + '/' +  outdirbase + serv['name'] + '/regattas'
#       4     with open(filepath + '.json') as json_file:
#       5         print('file extracted: ', filepath)
#
# TypeError: string indices must be integers

# %% [markdown]
# ## races

# %%
# TABLE 2 races columns; 
# regatta
# race
# raceShort
# raceId
# maxWindSpd_kts
# minWindSpd_kts
# avgWindDir_deg
# firstlegbearing_deg

# coming from races, windsummary and firstlegbearing
filenames = ['races', 'windsummary', 'firstlegbearing']

for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        directory_regatta = parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                            webAddressToFilename(regattaLoc(regName))
        filepath = directory_regatta + 'races.json'
        with open(filepath) as json_file:
            print('file extracted: ', filepath)
            data = json.load(json_file)
        dic_data = {'regatta': regName, 'data': data}
        races = cd.transformJsonToPD(dic_data, 'races')
        
        
        filepath = directory_regatta + 'windsummary.json'
        with open(filepath) as json_file:
            print('file extracted: ', filepath)
            data = json.load(json_file)
        dic_data = {'regatta': regName, 'data': data}
        windsummary = cd.transformJsonToPD(dic_data, 'windsummary').set_index(['regatta', 'raceShort'])   
        
        flb = []
        for index, race in races.iterrows():
            directory_race = parentdir + '/' + outdirbase +serv['name'] + \
                             webAddressToFilename(raceLoc(regName, race['race']))
            filepath = directory_race + 'firstlegbearing.json'
            with open(filepath) as json_file:
#                 print('file extracted: ', filepath)
                data = json.load(json_file)
            dic_data = {'regatta': regName, 'race': race['race'], 'data': data}
            firstlegbearing = cd.transformJsonToPD(dic_data, 'firstlegbearing') 
            flb.append(firstlegbearing)
        flb = pd.concat(flb).set_index(['regatta', 'race'])
        
    
        races = races.set_index(['regatta','raceShort'])
        result = pd.concat([races, windsummary], axis=1, join='outer').reset_index().set_index(['regatta', 'race'])
        result = pd.concat([result, flb], axis=1, join='outer').reset_index()
        
#         print('with as result', result)
        
        try:
            result.to_sql('races', con = engine, index = False, if_exists = 'append')
            print('Succesfully added races of {} {} to the database'.format(regName, race['race']))
        except IntegrityError as e:
            print('Could not add races of {} {} to the database because of IntegrityError: {}'.format(regName,race['race'],e))

# %%
## add begin and end time to races
for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        print(regName)
        dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                    webAddressToFilename(regattaLoc(regName)) + '/races/'
        for race in os.listdir(dir_races):
            filepath = dir_races + race + "/times.json"
            with open(filepath) as json_file:
#                     print('file extracted: ', filepath)
                data = json.load(json_file)
            dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}
            df = cd.transformJsonToPD(dic_data, 'times')#.set_index(['regatta', 'comp_name']) 

            times = [df['startOfRace-ms'].values[0],df['endOfRace-ms'].values[0]]
            if times[0] is None:
                continue
#             #update
            cursor.execute("""
                UPDATE races
                SET    races.[startOfRace-ms] = {}
                       ,races.[endOfRace-ms] = {}
                WHERE
                regatta = '{}'
                  and race = '{}'
                  """.format(df['startOfRace-ms'].values[0],df['endOfRace-ms'].values[0] 
                             , regName , filenameToWebAddress(race))
                          )
            cursor.commit()

# %% [markdown]
# ## competitors

# %%
## TABLE 3 Competitors
for serv in eventSelection:
    d = download.download(server = serv['name'], regattasContaining = serv['regattaNameContaining'],\
    racesContaining = serv['raceNameContaining'])
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        
        directory_regatta =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) +\
                                webAddressToFilename(regattaLoc(regName))
        filepath = directory_regatta + 'entries.json'
        with open(filepath) as json_file:
#             print('file extracted: ', filepath)
            data = json.load(json_file)
        dic_data = {'regatta': regName, 'data': data}
        competitors = cd.transformJsonToPD(dic_data, 'entries').set_index(['regatta', 
                                                                          'comp_name'])
#         print(competitors.head())


        dir_datamining =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                        webAddressToFilename(regattaLoc(regName)) + '/datamining/'
        datamining_reg = []
        for root, dirs, files in os.walk(dir_datamining, topdown=True):
            for file in files:
                fname = os.path.splitext(file)[0]
                if file.endswith(".json"):
                    with open(root + file) as json_file:
#                         print('file extracted: ', root + file)
                        data = json.load(json_file)
                    dic_data = {'regatta': regName, 'data': data}
                    df = cd.transformJsonToPD(dic_data, fname).set_index(['regatta', 'comp_name']) 
                    datamining_reg.append(df)
#                   print('df: ',df.head())

        datamining_reg = pd.concat(datamining_reg, axis = 1, join = 'outer')
            
        result = pd.merge(datamining_reg.reset_index(), competitors.reset_index(), how='left')
#         print('comp', result.head())
        result.to_sql('competitors', con = engine, index = False, if_exists = 'append')
        print('Succesfully uploaded competitors from {} to sql server'.format(regName))

# %% [markdown]
# ## windsources & wind

# %%
sql = """SELECT  [regatta]
      ,[race]
  FROM [dbo].[race_comp] as rc
  group by regatta, race
  Having max(pos_startline_rel) is Null
"""


eventSelection = pd.read_sql(sql, con= engine)
eventSelection

sql = """SELECT  windsources.regatta, windsources.race, avg(stl_bearing_diff_wind)  from races INNER JOIN 
windsources on windsources.regatta = races.regatta and windsources.race = races.race
where stl_bearing_diff_wind is not null
group by windsources.regatta, windsources.race
having MAX(CAST(rc as INT)) is null
"""


eventSelection = pd.read_sql(sql, con= engine)
eventSelection
# Out:
#                             regatta             race
# 0                Tokyo 2019 - Laser  R7 (Laser Int.)  -1.75
# 1                Tokyo 2019 - Laser  R8 (Laser Int.)   0.00
# 2             Tokyo 2019 - RS:X Men    R3 (RS:X Men)   0.88
# 3          WCS 2019 Enoshima - Finn               R6   4.43
# 4         WCS 2019 Enoshima - Laser               R2  -0.98
# 5         WCS 2019 Enoshima - Laser               R8   4.13
# 6         WCS 2019 Enoshima - Laser               R9  13.38
# 7  WCS 2019 Enoshima - Laser Radial               R2  -1.10

# %%
## Table 4 wind

for indx, row in eventSelection.iterrows():    
    regName = row.regatta
    raceName = row.race

# for serv in eventSelection:
#     for indx, regatta in serv['regattas'].iterrows():
#         regName = regatta.regatta
#         dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
#                         webAddressToFilename(regattaLoc(regName)) + '/races/'
        
#         for race in os.listdir(dir_races):
#             raceName = filenameToWebAddress(race)
    ## quick check whether there are already windsources loaded
    print('Get first pos windsources', end = '\r')
    sql = """ SELECT * FROM {}
            WHERE regatta = '{}'
            and race = '{}'
          """.format('windsources', regName, raceName)
    check = pd.read_sql(sql, con = engine) ## already a positions for this race ?   
    if check.empty:
#                     print('\tAlready positions found in wind for \t{} \t{} \t{}'.format(regName, raceName, ws.typeName, ws.id))
        print('Fetch windsources data', end = '\r')        
        url_ws = windUrl(regName, raceName)
        data = requests.get(url_ws, timeout = 100)

        if data.status_code == 404:
            print('No windsources available for {} {}'.format(regName, raceName))
            continue
        data = data.json()
        print('Transform windsources data', end = '\r')        
        df = cd.transformJsonToPD(data, 'windsources')
        toSql(df,'windsources', engine, regName, raceName)
    else:
        df = check

    for idx, ws in df.iterrows():
        ## quick check whether there are already entries
        if ws.typeName != "EXPEDITION":
            continue
 
        print('Get first pos wind        ', end = '\r')
        sql = """ SELECT TOP (1) * FROM {}
                WHERE regatta = '{}'
                and race = '{}'
                and windSource = 'EXPEDITION'
                and windSource_id = '{}'
              """.format('wind', regName, raceName,  ws.id)
        check = pd.read_sql(sql, con = engine) ## already a positions for this race ?   
        if not check.empty:
#                     print('\tAlready positions found in wind for \t{} \t{} \t{}'.format(regName, raceName, ws.typeName, ws.id))
            continue
        print('load data from url', end = '\r')
        url_wind = windUrl(regName, raceName, windSource = ws.typeName, windSourceId = ws.id)
        data = requests.get(url_wind, timeout = 100)
        if data.status_code == 400:
            print('\tNo wind available for {} {} {}'.format(regName, raceName, ws.typeName))
            continue
        data = data.json()
        df = cd.transformJsonToPD(data, 'wind')
        if df.empty:
            print('\tNo wind available for {} {} {} {}'.format(regName, raceName, ws.typeName, ws.id))
            continue            
        df.windSource = df.windSource.apply(lambda x: ws.typeName)
        df['windSource_id'] = df.windSource.apply(lambda x: ws.id)
        print('Upload wind data to sql server', end = '\r')
        print(url_wind)
        e = toSql(df, 'wind', engine, regName, raceName + ws.typeName + ws.id)
# Out:
# 	No wind available for WCS 2019 Enoshima - Laser R8 EXPEDITION DC-FE-AAGF
# 	No wind available for WCS 2019 Enoshima - Laser R8 EXPEDITION DC-FE-AAHG
# 	No wind available for WCS 2019 Enoshima - Laser R8 EXPEDITION DC-GD-AAAE
# 	No wind available for WCS 2019 Enoshima - Laser R8 EXPEDITION DC-GD-AADA
# 	No wind available for WCS 2019 Enoshima - Laser R8 EXPEDITION DD-EE-AAHE
# 	No wind available for WCS 2019 Enoshima - Laser R9 EXPEDITION DC-FE-AAGF
# 	No wind available for WCS 2019 Enoshima - Laser R9 EXPEDITION DC-FE-AAHG
# 	No wind available for WCS 2019 Enoshima - Laser R9 EXPEDITION DC-GD-AAAE
# 	No wind available for WCS 2019 Enoshima - Laser R9 EXPEDITION DC-GD-AADA
# 	No wind available for WCS 2019 Enoshima - Laser R9 EXPEDITION DD-EE-AAHE
# Get first pos wind

# %%
url_wind
# Out:
# 'https://www.sapsailing.com/sailingserver/api/v1/regattas/WCS 2019 Enoshima - Laser/races/R9/wind?windsource=EXPEDITION&windsourceid=DD-EE-AAHE&fromtime=2012-01-01T10:12:03Z&totime=2050-12-31T10:12:03Z'

# %% [markdown]
# ## legs

# %%
## TABLE 5 legs
# [regatta]
# ,[race]
# ,[leg_nr]
# ,[fromWaypointId]
# ,[toWaypointId]
# ,[to]
# ,[from]
# ,[upOrDownwindLeg]
# ,[leg_nr_from_finish]
# ,[distance]


for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                        webAddressToFilename(regattaLoc(regName)) + '/races/'
        for race in os.listdir(dir_races):
            filepath = dir_races + race + "/competitors/legs.json"
            if filepath.endswith(".json"):
                with open(filepath) as json_file:
#                     print('file extracted: ', filepath)
                    data = json.load(json_file)
                dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}
                df = cd.transformJsonToPD(dic_data, 'legs') 
#                 print('df: ',df.head())

                try:
                    df.to_sql('legs', con = engine, index = False, if_exists = 'append')
                    print('Succesfully uploaded wind for regatta: \t{}, race: \t{}'.format(regName, race))
                except IntegrityError as e:
                    print('WARNING: Failed to upload to sql: '+ str(e))

# %% [markdown]
# ## race_comp

# %% [raw]
# ### temorarily delete entries in comp_leg, because I accidentally deleted to many similar rows
#
# cursor.execute("""
# DELETE FROM legs;
# """)

# %%
### TABLE 6
## This code create all entries in race_comp. We do this by checking that the nr_competitors in 
## the races table is still NULL because we did not update that yet.
## We will later add rank, based on comp_leg
cursor.execute("""
INSERT INTO race_comp(regatta, race, comp_id)
SELECT races.regatta, races.race, competitors.comp_id FROM races, competitors
WHERE races.regatta = competitors.regatta
 and races.nr_competitors IS NULL
""")

# %% [markdown]
# ## comp_leg

# %%
## TABLE 7 comp_leg
# [regatta]
# ,[race]
# ,[leg_nr]
# ,[comp_id]
# ,[competitor_distanceTraveled-m]
# ,[competitor_averageSOG-kts]
# ,[competitor_tacks]
# ,[competitor_jibes]
# ,[competitor_penaltyCircles]
# ,[competitor_rank]
# ,[competitor_gapToLeader-s]
# ,[competitor_gapToLeader-m]
# ,[competitor_started]
# ,[competitor_finished]




for serv in eventSelection:
    
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                    webAddressToFilename(regattaLoc(regName)) + '/races/'
        for race in os.listdir(dir_races):
            filepath = dir_races + race + "/competitors/legs.json"
            if filepath.endswith(".json"):
                with open(filepath) as json_file:
#                     print('file extracted: ', filepath)
                    data = json.load(json_file)
                dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}
                df = cd.transformJsonToPD(dic_data, 'comp_leg') 
#                 print('df: ',df.head())



                try:
                    df.to_sql('comp_leg', con = engine, index = False, if_exists = 'append')
                    print('Succesfully uploaded wind for regatta: \t{}, race: \t{}'.format(regName, race))
                except IntegrityError as e:
                    print('Could not add races of {} {} to the database because of IntegrityError: {}'.format(regName,
                                                                                                              race,
                                                                                                              e))

# %%
### Markpassings, to update legnr_columnn in positions

cursor.execute("""
DROP TABLE temp_markpassings
CREATE TABLE temp_markpassings
(regatta varchar(50) NOT NULL,
race varchar(50) NOT NULL,
comp_id binary(16) NOT NULL,
leg_nr int NOT NULL,
begin_leg_ms bigint NULL,
end_leg_ms bigint NULL

)

CREATE UNIQUE INDEX idx ON temp_markpassings (regatta, race, leg_nr, comp_id);
CREATE CLUSTERED INDEX idx_2 ON temp_markpassings (regatta, race, comp_id);

""")

cursor.execute("""
ALTER TABLE temp_markpassings
ADD CONSTRAINT fk_temp_markpassings_comp_leg FOREIGN KEY (regatta, race, leg_nr, comp_id)
      REFERENCES comp_leg (regatta, race, leg_nr, comp_id)
      ON DELETE CASCADE
      ON UPDATE CASCADE
""")

# %%
#### TEMPORARY TABLE MARKPASSINGS
for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) +\
                    webAddressToFilename(regattaLoc(regName)) + '/races/'
        for race in os.listdir(dir_races):
            filepath = dir_races + race + "/markpassings.json"
            with open(filepath) as json_file:
#                 print('file extracted: ', filepath)
                data = json.load(json_file)
            dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}
            df = cd.transformJsonToPD(dic_data, 'markpassings') 
            if not df.empty:
#                 print(df.leg_nr.unique())
                try:                
                    df.to_sql('temp_markpassings', con = engine, index = False, if_exists = 'append')

                    print('Succesfully added markpassings of \t{} \t{} \tto the database'.format(regName, race))
                except IntegrityError as e:
                    print('Could not add markpassings of \t{} \t{} \tto the database because of IntegrityError:'.format(regName,race))

                    
                    else:
                print('Warning: markpassings for \t{} \t{} \t was empty'.format(regName, race))

# %% [markdown]
# ## positions

# %%
sql = """
SELECT * from legs 
where pos_startline_abs_x IS NULL and
correlation_side is not null
and leg_nr = 1

"""


eventSelection = pd.read_sql(sql, con= engine)
eventSelection
# Out:
#                              regatta                    race  leg_nr  \
# 0            Tokyo 2019 - RS:X Women         R1 (RS:X Women)       1
# 1            Tokyo 2019 - RS:X Women        R10 (RS:X Women)       1
# 2            Tokyo 2019 - RS:X Women        R11 (RS:X Women)       1
# 3            Tokyo 2019 - RS:X Women  R12 Medal (RS:X Women)       1
# 4            Tokyo 2019 - RS:X Women         R2 (RS:X Women)       1
# 5            Tokyo 2019 - RS:X Women         R3 (RS:X Women)       1
# 6            Tokyo 2019 - RS:X Women         R4 (RS:X Women)       1
# 7            Tokyo 2019 - RS:X Women         R5 (RS:X Women)       1
# 8            Tokyo 2019 - RS:X Women         R6 (RS:X Women)       1
# 9            Tokyo 2019 - RS:X Women         R7 (RS:X Women)       1
# 10           Tokyo 2019 - RS:X Women         R8 (RS:X Women)       1
# 11           Tokyo 2019 - RS:X Women         R9 (RS:X Women)       1
# 12            Toyko 2019 - 470 Women          R3 (470 Women)       1
# 13         Tokyo 2019 - Laser Radial       R7 (Laser Radial)       1
# 14              Tokyo 2019 - 470 Men            R8 (470 Men)       1
# 15             Tokyo 2019 - RS:X Men           R1 (RS:X Men)       1
# 16             Tokyo 2019 - RS:X Men          R10 (RS:X Men)       1
# 17             Tokyo 2019 - RS:X Men    R11 Medal (RS:X Men)       1
# 18             Tokyo 2019 - RS:X Men           R2 (RS:X men)       1
# 19             Tokyo 2019 - RS:X Men           R3 (RS:X Men)       1
# 20             Tokyo 2019 - RS:X Men           R4 (RS:X Men)       1
# 21             Tokyo 2019 - RS:X Men           R5 (RS:X Men)       1
# 22             Tokyo 2019 - RS:X Men           R6 (RS:X Men)       1
# 23             Tokyo 2019 - RS:X Men           R7 (RS:X Men)       1
# 24             Tokyo 2019 - RS:X Men           R8 (RS:X Men)       1
# 25             Tokyo 2019 - RS:X Men           R9 (RS:X Men)       1
# 26                 Tokyo 2019 - Finn               R8 (Finn)       1
# 27             Tokyo 2019 - Nacra 17           R6 (Nacra 17)       1
# 28       HWCS 2020 Round 1 - 470 Men            R1 (470 Men)       1
# 29  WCS 2019 Enoshima - Laser Radial                      R6       1
# 30  WCS 2019 Enoshima - Laser Radial                      R7       1
#
#                                        fromWaypointId  \
# 0   b'\xe4$\x14r\xf2\xbcI\xed\x8a,\xaa\xa6+\x89\xfdD'
# 1   b'\xe1\x8a\xde\x81\x06<O\xfe\x84\xae\x1e\x0e_5...
# 2   b'i\xde\x9c\x00n\x80K9\x92\xb1\x91\x1c\x1ad\xb...
# 3         b'\xa9\x8c}b\xa3\x04N<\x99F\x85]l\xa9#\xcd'
# 29  b'\x83\xfa\xac\x88,\xaaH\xc0\xaf\x1f:\x8f&\xed...    None       Start
# 30     b'\x8f\xfc\x8d%\xcd\xc7@<\xb6I^\x8b7\xe5Y\xae'    None       Start
#
#     upOrDownwindLeg  leg_nr_from_finish distance  correlation_tacks  \
# 0              True                   5     None            -0.2586
# 1              True                   6     None             0.2426
# 2              True                   6     None             0.1065
# 3              True                   5     None             0.7977
# 4              True                   5     None             0.5290
# 5              True                   5     None             0.1621
# 6             False                   5     None             0.0264
# 7              True                   5     None             0.1503
# 8              True                   6     None             0.1253
# 9              True                   6     None             0.4822
# 10             True                   6     None            -0.2927
# 11             True                   6     None             0.3496
# 12             True                   6     None             0.5081
# 13             True                   5     None             0.7240
# 14             True                   7     None             0.4521
# 15             True                   5     None             0.5771
# 16             True                   6     None             0.4972
# 17             True                   5     None            -0.3137
# 18             True                   5     None             0.6768
# 19             True                   5     None             0.1628
# 20             True                   5     None             0.3095
# 21             True                   6     None             0.6757
# 22             True                   6     None             0.2840
# 23            False                   6     None            -0.3926
# 24             True                   6     None             0.2664
# 25             True                   6     None             0.4606
# 26             True                   5     None             0.3544
# 27             True                   9     None            -0.0579
# 28             True                   6     None             0.4759
# 29             True                   6     None             0.3512
# 30             True                   6     None             0.6881
#
#     correlation_side  correlation_avgSOG  correlation_traveledDistance  \
# 0             0.3705             -0.2870                        0.7203
# 1            -0.1444             -0.0804                        0.6309
# 2             0.7157             -0.2676                        0.5755
# 3            -0.6687             -0.8099                       -0.3754
# 4             0.2411             -0.3134                        0.6899
# 5             0.0339             -0.3196                        0.8389
# 6            -0.4246             -0.8082                        0.5028
# 7            -0.7553             -0.2778                        0.4595
# 8             0.0114             -0.4016                        0.0433
# 9            -0.4148             -0.6537                        0.1701
# 10           -0.0836             -0.6653                        0.4041
# 11            0.5709             -0.5142                        0.5117
# 12           -0.2149              0.0140                        0.8199
# 13           -0.4561             -0.4274                        0.7117
# 14            0.2347             -0.3939                        0.4708
# 15           -0.7315             -0.8084                        0.8809
# 16            0.5411             -0.0009                        0.8361
# 17            0.6011             -0.7550                        0.4997
# 18           -0.7477             -0.8496                        0.4880
# 19           -0.1282             -0.1095                        0.9224
# 20           -0.4365             -0.7956                        0.6521
# 21           -0.6491             -0.5574                        0.7655
# 22            0.2105             -0.6364                        0.4214
# 23            0.9258             -0.5379                        0.6914
# 24           -0.3811             -0.4355                        0.6321
# 25           -0.1764             -0.6440                       -0.1748
# 26            0.6338             -0.4318                        0.4265
# 27            0.0749             -0.2292                        0.6988
# 28            0.0800             -0.6171                        0.3759
# 29            0.0879             -0.5070                        0.7922
# 30           -0.9082             -0.7509                        0.7652
#
#     correlation_jibes pos_startline_abs_x pos_startline_abs_y  \
# 0                 NaN                None                None
# 1              0.1636                None                None
# 2                 NaN                None                None
# 3                 NaN                None                None
# 4                 NaN                None                None
# 5                 NaN                None                None
# 6             -0.0871                None                None
# 7                 NaN                None                None
# 8                 NaN                None                None
# 9                 NaN                None                None
# 10                NaN                None                None
# 11                NaN                None                None
# 12             0.3780                None                None
# 13             0.5436                None                None
# 14                NaN                None                None
# 15             0.3024                None                None
# 16                NaN                None                None
# 17             0.5222                None                None
# 18             0.3620                None                None
# 19                NaN                None                None
# 20            -0.0421                None                None
# 21             0.0942                None                None
# 22             0.3438                None                None
# 23             0.3527                None                None
# 24            -0.2594                None                None
# 25             0.0356                None                None
# 26                NaN                None                None
# 27            -0.1393                None                None
# 28                NaN                None                None
# 29                NaN                None                None
# 30            -0.0658                None                None
#
#    pos_startline_rel cor_side_pos_startline_abs cor_side_pos_startline_rel
# 0               None                       None                       None
# 1               None                       None                       None
# 2               None                       None                       None
# 3               None                       None                       None
# 4               None                       None                       None
# 5               None                       None                       None
# 6               None                       None                       None
# 7               None                       None                       None
# 8               None                       None                       None
# 9               None                       None                       None
# 10              None                       None                       None
# 11              None                       None                       None
# 12              None                       None                       None
# 13              None                       None                       None
# 14              None                       None                       None
# 15              None                       None                       None
# 16              None                       None                       None
# 17              None                       None                       None
# 18              None                       None                       None
# 19              None                       None                       None
# 20              None                       None                       None
# 21              None                       None                       None
# 22              None                       None                       None
# 23              None                       None                       None
# 24              None                       None                       None
# 25              None                       None                       None
# 26              None                       None                       None
# 27              None                       None                       None
# 28              None                       None                       None
# 29              None                       None                       None
# 30              None                       None                       None

# %%
## TABLE 8 positions

for ids, row in eventSelection.iterrows():
    regName = row.regatta
    raceName = row.race
    
    print('Get first positions\t\t\t', end = '\r')
    sql = """ SELECT * FROM {}
            WHERE regatta = '{}'
            and race = '{}'
          """.format('positions', regName, raceName)
    check = pd.read_sql(sql, con = engine) ## already a positions for this race ?   
    if not check.empty:
        print('Already positions found in db for \t{} \t{}'.format(regName, raceName))
        continue

    print('get markpassings\t\t\t', end="\r")
    sql = """ SELECT * FROM temp_markpassings
            WHERE regatta = '{}'
            and race = '{}'
            """.format(regName, raceName)
    mps = pd.read_sql(sql, con = engine) ## markpassings for this race
    if mps.empty:
        print('No markpassings where found for\t{} \t{}'.format(regName, raceName))
        continue        
        
    print('Fetch positions data\t\t\t', end = '\r')        
    url_ws = dataUrl(regName, raceName, 'positions_comp')
    data = requests.get(url_ws, timeout = 100)

    if data.status_code == 404:
        print('No positions available for {} {}'.format(regName, raceName))
        continue
    data = data.json()
    
    dic_data = {'regatta': regName, 'race': raceName, 'data': data}
    print('Transform positions data\t\t\t', end = '\r')        
    df = cd.transformJsonToPD(dic_data, 'competitor_positions')

    print('determine leg numbers\t\t\t', end="\r")
    for idx, comp_leg in mps.iterrows():
        df.loc[(df.comp_id == comp_leg.comp_id) & (df['timepoint_ms'] > comp_leg.begin_leg_ms)
               & (df['timepoint_ms'] < comp_leg.end_leg_ms),'leg_nr'] = comp_leg.leg_nr
    df = df.dropna(subset=['leg_nr'])
    
    toSql(df,'positions', engine, regName, raceName)
# Out:
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R1 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R10 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R11 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R12 Medal (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R2 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R3 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R4 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R5 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R6 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R7 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R8 (RS:X Women)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Women, race: 	R9 (RS:X Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R3 (470 Women)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R7 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R8 (470 Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R1 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R10 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R11 Medal (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R2 (RS:X men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R3 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R4 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R5 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R6 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R7 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R8 (RS:X Men)
# Succesfully uploaded positions for regatta: 	Tokyo 2019 - RS:X Men, race: 	R9 (RS:X Men)
# Already positions found in db for 	Tokyo 2019 - Finn 	R8 (Finn)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R6 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R1 (470 Men)
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R7

# %%
# quick import when a positions file was truncated 

import urllib, json, requests

servName = 'hwcs2020-round1'
regName = 'HWCS 2020 Round 1 - Finn'
raceName = 'R6 (FINN)'

url = 'https://www.sapsailing.com/sailingserver/api/v1/regattas/{}/races/{}/competitors/positions'.format(regName,
                                                                                                          raceName)
filename = '{}/data/raw/{}/regattas/{}/races/{}/competitors/positions.json'.format(parentdir, servName, regName, raceName)
try:
    r = requests.get(url).json()
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    print(filename)
except ValueError:
    print("Oops! ", loc , " did not contain the right data for the races")

with open(filename, 'w+') as outfile:
    print('Created new file:', filename)
    json.dump(r, outfile)

# %% [markdown]
# ## courses

# %%
## Table 9 courses


for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                        webAddressToFilename(regattaLoc(regName)) + '/races/'
        for race in os.listdir(dir_races):
            filepath = dir_races + race + "/course.json"
            with open(filepath) as json_file:
#               print('file extracted: ', filepath)
                data = json.load(json_file)
            dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}
            df = cd.transformJsonToPD(dic_data, 'course') 
#             print('df: ', df.head())

            try:
                df.to_sql('courses', con = engine, index = False, if_exists = 'append')
                print('Succesfully uploaded courses for regatta: \t{}, race: \t{}'.format(regName, race))
            except IntegrityError as e:
                df
                print('WARNING: Failed to upload to sql: '+ str(e))

# %% [markdown]
# ## marks

# %%
## Table 10 marks

for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                        webAddressToFilename(regattaLoc(regName)) + '/races/'
        for race in os.listdir(dir_races):
            
            print('Get first marks', end = '\r')
            sql = """ SELECT TOP (1) * FROM marks
                    WHERE regatta = '{}'
                    and race = '{}'
                  """.format(filenameToWebAddress(regName), filenameToWebAddress(race))
            pos = pd.read_sql(sql, con = engine) ## already a positions for this race ?   
            if not pos.empty:
                print('Already positions found in db for \t{} \t{}'.format(regName, race))
                continue

            filepath = dir_races + race + "/marks/positions.json"
            with open(filepath) as json_file:
#               print('file extracted: ', filepath)
                data = json.load(json_file)
            dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}
            df = cd.transformJsonToPD(dic_data, 'marks') 
#             print('df: ', df)

            try:
                df.to_sql('marks', con = engine, index = False, if_exists = 'append')
                print('Succesfully uploaded marks for regatta: \t{}, race: \t{}'.format(regName, race))
            except IntegrityError as e:
                print(df.head())
                print('WARNING: Failed to upload to sql: \t{}, race: \t{}, {}'.format(regName, race, e))
# Out:
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	M Medal (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R08 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R09 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R1 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R10 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R2 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R3 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R4 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R5 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R6 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R7 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	M Medal (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R08 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R09 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R1 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R10 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R2 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R3 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R4 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R5 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R6 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R7 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	M Medal (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R1(49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R2(49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R3 (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R4 (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R5 (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	M Medal (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R1 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R2 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R3 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R4 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R5 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	M Medal (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R08 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R09 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R1 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R10 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R2 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R3 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R4 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R5 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R6 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R7 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	M Medal (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R1 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R10 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R11 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R12 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R2 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R3 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R4 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R5 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R6 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R7 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R8 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R9 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	M Medal (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R08 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R09 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R1 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R10 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R2 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R3 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R4 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R5 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R6 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R7 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	M Medal (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R1 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R10 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R2 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R3 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R4 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R5 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R6 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R7 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R8 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R9 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	M Medal (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R1 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R2 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R3 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R4 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R5  (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R6 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R7 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	M Medal (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R08 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R09 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R1 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R10 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R2 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R3 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R4 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R5 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R6 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R7 (470 Women)
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	M Medal (Laser)
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R8
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R9
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	M Medal (RS__X Men)
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R1
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R2
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R3
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R4
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R5
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R6
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R7
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	M Medal (49er)
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R7
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R9
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	M Medal (Nacra 17)
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R8
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R9
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	M Medal (RS__X Women)
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R1
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R2
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R3
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R4
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R5
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R6
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R7
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	M Medal (49erFX)
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	M Medal (Laser Radial)
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R8
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R9
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R7
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R7
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R8
# Already positions found in db for 	Tokyo 2019 - 49er 	R1 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R10 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R11 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R12 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R13 Medal (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R2 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R3 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R4 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R5 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R6 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R7 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R8 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R9 (49er)
# Already positions found in db for 	Tokyo 2019 - Laser 	R1 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R10 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R2 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R3 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R4 (Laser Int.)
# 7382d0e0-a46f-0137-9c65-48f75048232a (2) badly formed hexadecimal UUID string
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser, race: 	R5 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R6 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R7 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R8 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R9 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R1 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R10 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R11 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R12 Medal (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R2 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R3 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R4 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R5 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R6 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R7 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R8 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - RS:X Women 	R9 (RS__X Women)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R1 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R10 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R11 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R12 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R13 Medal (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R2 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R3 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R4 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R5 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R6 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R7 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R8 (49erFX)
# Already positions found in db for 	Tokyo 2019 - 49er FX 	R9 (49erFX)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R1 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R10 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R11 Medal (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R2 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R3 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R4 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R5 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R6 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R7 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R8 (470 Women)
# Already positions found in db for 	Toyko 2019 - 470 Women 	R9 (470 Women)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R1 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R10 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R2 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R3 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R4 (Laser Radial)
# 7382d0e0-a46f-0137-9c65-48f75048232a (2) badly formed hexadecimal UUID string
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R5 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R6 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R7 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R8 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - Laser Radial 	R9 (Laser Radial)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R1 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R10 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R2 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R3 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R4 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R5 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R6 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R7 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R8 (470 Men)
# Already positions found in db for 	Tokyo 2019 - 470 Men 	R9 (470 Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R1 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R10 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R11 Medal (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R2 (RS__X men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R3 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R4 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R5 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R6 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R7 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R8 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - RS:X Men 	R9 (RS__X Men)
# Already positions found in db for 	Tokyo 2019 - Finn 	R1 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R10 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R2 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R3 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R4 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R5 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R6 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R7 (Finn)
# f1274e80-a537-0137-b78b-48f75048232a (2) badly formed hexadecimal UUID string
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R8 (Finn)
# Already positions found in db for 	Tokyo 2019 - Finn 	R9 (Finn)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R1 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R10 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R11 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R12 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R13 Medal (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R2 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R3 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R4 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R5 (Nacra 17)
# 1592b1b0-a463-0137-9a0c-48f75048232a (2) badly formed hexadecimal UUID string
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R6 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R7 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R8 (Nacra 17)
# Already positions found in db for 	Tokyo 2019 - Nacra 17 	R9 (Nacra 17)

# %% [markdown]
# ## marks_positions

# %%
## Table 9 marks_positions

for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                        webAddressToFilename(regattaLoc(regName)) + '/races/'
        for race in os.listdir(dir_races):
            
            print('Get first pos', end = '\r')
            sql = """ SELECT TOP (1) * FROM marks_positions
                    WHERE regatta = '{}'
                    and race = '{}'
                  """.format(filenameToWebAddress(regName), filenameToWebAddress(race))
            pos = pd.read_sql(sql, con = engine) ## already a positions for this race ?   
            if not pos.empty:
                print('Already positions found in db for \t{} \t{}'.format(regName, race))
                continue
                
            filepath = dir_races + race + "/marks/positions.json"
            with open(filepath) as json_file:
                data = json.load(json_file)
            dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}
            df = cd.transformJsonToPD(dic_data, 'marks_positions') 

#             print('df: ', df)
            print('uploading to sql', end = '\r')
            try:
                df.to_sql('marks_positions', con = engine, index = False, if_exists = 'append')
                print('Succesfully uploaded marks for regatta: \t{}, race: \t{}'.format(regName, race))
            except IntegrityError as e:
                print('WARNING: Failed to upload to sql: \t{}, race: \t{}'.format(regName, race))
# Out:
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	M Medal (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R08 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R09 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R1 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R10 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R2 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R3 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R4 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R5 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R6 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser 	R7 (Laser Standard)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	M Medal (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R08 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R09 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R1 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R10 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R2 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R3 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R4 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R5 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R6 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - Laser Radial 	R7 (Laser Radial)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	M Medal (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R1(49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R2(49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R3 (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R4 (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - 49erFX 	R5 (49FX)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	M Medal (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R1 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R2 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R3 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R4 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - Nacra 17 	R5 (Nacra 17)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	M Medal (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R08 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R09 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R1 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R10 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R2 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R3 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R4 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R5 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R6 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Men 	R7 (470 Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	M Medal (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R1 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R10 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R11 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R12 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R2 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R3 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R4 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R5 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R6 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R7 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R8 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Men 	R9 (RSX Men)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	M Medal (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R08 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R09 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R1 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R10 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R2 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R3 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R4 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R5 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R6 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - Finn 	R7 (FINN)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	M Medal (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R1 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R10 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R2 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R3 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R4 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R5 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R6 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R7 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R8 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - RS:X Women 	R9 (RSX Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	M Medal (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R1 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R2 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R3 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R4 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R5  (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R6 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 49er 	R7 (49ER)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	M Medal (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R08 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R09 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R1 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R10 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R2 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R3 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R4 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R5 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R6 (470 Women)
# Already positions found in db for 	HWCS 2020 Round 1 - 470 Women 	R7 (470 Women)
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	M Medal (Laser)
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R8
# Already positions found in db for 	WCS 2019 Enoshima - Laser 	R9
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	M Medal (RS__X Men)
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R1
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R2
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R3
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R4
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R5
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R6
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R7
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Men 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	M Medal (49er)
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R7
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 49er 	R9
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	M Medal (Nacra 17)
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R8
# Already positions found in db for 	WCS 2019 Enoshima - Nacra 17 	R9
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	M Medal (RS__X Women)
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R1
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R2
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R3
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R4
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R5
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R6
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R7
# Already positions found in db for 	WCS 2019 Enoshima - RS:X Women 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	M Medal (49erFX)
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 49erFX 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	M Medal (Laser Radial)
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Laser Radial 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R1
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R2
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R3
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R4
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R5
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R6
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R7
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R8
# Already positions found in db for 	WCS 2019 Enoshima - Finn 	R9
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R7
# Already positions found in db for 	WCS 2019 Enoshima - 470 Women 	R8
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R1
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R2
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R3
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R4
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R5
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R6
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R7
# Already positions found in db for 	WCS 2019 Enoshima - 470 Men 	R8
# Already positions found in db for 	Tokyo 2019 - 49er 	R1 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R10 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R11 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R12 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R13 Medal (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R2 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R3 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R4 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R5 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R6 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R7 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R8 (49er)
# Already positions found in db for 	Tokyo 2019 - 49er 	R9 (49er)
# Already positions found in db for 	Tokyo 2019 - Laser 	R1 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R10 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R2 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R3 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R4 (Laser Int.)
# 7382d0e0-a46f-0137-9c65-48f75048232a (2) badly formed hexadecimal UUID string
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser, race: 	R5 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R6 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R7 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R8 (Laser Int.)
# Already positions found in db for 	Tokyo 2019 - Laser 	R9 (Laser Int.)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R1 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R10 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R11 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R12 Medal (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R2 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R3 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R4 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R5 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R6 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R7 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R8 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Women, race: 	R9 (RS__X Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R1 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R10 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R11 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R12 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R13 Medal (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R2 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R3 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R4 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R5 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R6 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R7 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R8 (49erFX)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 49er FX, race: 	R9 (49erFX)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R1 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R10 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R11 Medal (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R2 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R3 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R4 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R5 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R6 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R7 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R8 (470 Women)
# Succesfully uploaded marks for regatta: 	Toyko 2019 - 470 Women, race: 	R9 (470 Women)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R1 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R10 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R2 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R3 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R4 (Laser Radial)
# 7382d0e0-a46f-0137-9c65-48f75048232a (2) badly formed hexadecimal UUID string
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R5 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R6 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R7 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R8 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Laser Radial, race: 	R9 (Laser Radial)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R1 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R10 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R2 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R3 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R4 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R5 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R6 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R7 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R8 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - 470 Men, race: 	R9 (470 Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R1 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R10 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R11 Medal (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R2 (RS__X men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R3 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R4 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R5 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R6 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R7 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R8 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - RS:X Men, race: 	R9 (RS__X Men)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R1 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R10 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R2 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R3 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R4 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R5 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R6 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R7 (Finn)
# f1274e80-a537-0137-b78b-48f75048232a (2) badly formed hexadecimal UUID string
# WARNING: Failed to upload to sql: 	Tokyo 2019 - Finn, race: 	R8 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Finn, race: 	R9 (Finn)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R1 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R10 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R11 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R12 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R13 Medal (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R2 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R3 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R4 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R5 (Nacra 17)
# 1592b1b0-a463-0137-9a0c-48f75048232a (2) badly formed hexadecimal UUID string
# WARNING: Failed to upload to sql: 	Tokyo 2019 - Nacra 17, race: 	R6 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R7 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R8 (Nacra 17)
# Succesfully uploaded marks for regatta: 	Tokyo 2019 - Nacra 17, race: 	R9 (Nacra 17)

# %% [markdown]
# ## Extra functions in case something went wrong for a few entries

# %%
### Extra functions to manually add tracks of seperate competitors
## in the previous cell tracks have been added per race, but for some reason it went wrong in some cases

def uploadPositions(regName, race, comp_id):
    dir_races =  parentdir + '/' + outdirbase + webAddressToFilename(serv['name']) + \
                    webAddressToFilename(regattaLoc(regName)) + '/races/'
    filepath = dir_races + webAddressToFilename(race) + "/competitors/positions.json"
    sql = """ SELECT * FROM temp_markpassings
            WHERE regatta = '{}'
            and race = '{}'
            and comp_id = {}
            """.format(regName, race, comp_id)
    mps = pd.read_sql(sql, con = engine) ## markpassings for this race
    
    if mps.empty:
        print('No markpassings found, try to download them again')
    
    with open(filepath) as json_file:
#                     print('file extracted: ', filepath)
        data = json.load(json_file)
    dic_data = {'regatta': regName, 'race': filenameToWebAddress(race), 'data': data}

    print('transform to pd', end="\r")
    df = cd.transformJsonToPD(dic_data, 'competitor_positions') 

    print('determine leg numbers', end="\r")
    for idx, comp_leg in mps.iterrows():
        df.loc[(df.comp_id == comp_leg.comp_id) & (df['timepoint_ms'] > comp_leg.begin_leg_ms)
               & (df['timepoint_ms'] < comp_leg.end_leg_ms),'leg_nr'] = comp_leg.leg_nr
    df = df.dropna(subset=['leg_nr'])
#                 print(mps.head())
#                 print(df.head())

    try:
        print('Uploading positions to db', end="\r")
        df.to_sql('positions', con = engine, index = False, if_exists = 'append', chunksize = 10000)
        print('Added positions of \t{} \t{} \t succesfully to the database'.format(regName, race))
    except IntegrityError as e:
        print('Could not add positions of \t{} \t{} \tto the database because of IntegrityError.'.format(regName,race))
    return df

# %% [markdown]
# # Fill columns with extra information to complete database

# %% [markdown]
# ## Update final rank in race_comp

# %%
cursor.execute("""
UPDATE
    race_comp
SET
    race_comp.rank = (
            SELECT comp_leg.competitor_rank from comp_leg 
                    INNER JOIN legs ON comp_leg.regatta = legs.regatta
                                AND comp_leg.race = legs.race
                                AND comp_leg.leg_nr = legs.leg_nr
            WHERE legs.leg_nr_from_finish = 1
                AND race_comp.regatta = comp_leg.regatta 
                AND race_comp.race = comp_leg.race
                AND race_comp.comp_id = comp_leg.comp_id
)
""")

# %%
cnxn.commit()

# %% [markdown]
# ## Get chosen side of competitors for leg 1

# %%
for indx, row in eventSelection.iterrows():
    regName = row.regatta
    raceName = row.race

    sql = """SELECT  comp_leg.regatta, comp_leg.race, comp_leg.comp_id
                    ,comp_leg.competitor_started
                    ,comp_leg.competitor_finished
                    ,comp_leg.avg_side

            from comp_leg INNER JOIN regattas
            on regattas.regatta = comp_leg.regatta
            where regattas.regatta = '{}'
                  and leg_nr = 1""".format(regName)
    df = pd.read_sql_query(sql, con = engine)
    for index, row in df.iterrows():
        comp_id = "0x{}".format(row['comp_id'].hex().upper())

        sql = """SELECT  TOP (1) *
          FROM comp_leg
          WHERE regatta = '{}'
          and race = '{}'
          and comp_id = {}
          and leg_nr = 1""".format(regName , raceName , comp_id)
        comp_leg = pd.read_sql_query(sql, con = engine, chunksize=None)

        if not (comp_leg.avg_side.values[0] is None):
#             print(row['regatta'], row['race'] , comp_id , end="\t")
            print('{} {} {} Side already determined'.format(regName, raceName, comp_id))
            continue

        if not row['competitor_started'] or not row['competitor_finished']:
#             print(row['regatta'], row['race'] , comp_id , end="\t")
            print('{} {} {} Competitor did not finish leg'.format(regName, raceName, comp_id))
            continue


        sql = """SELECT  *
          FROM positions
          WHERE regatta = '{}'
          and race = '{}'
          and comp_id = {}
          and leg_nr = 1""".format(regName , raceName, comp_id)
        track = pd.read_sql_query(sql, con = engine, chunksize=None)

        if track.empty:
            print(regName, raceName, comp_id , end="\t")
            print('No track found, try to download it again', end = '\r')
#             uploadPositions(regName, raceName, comp_id)
#             sql = """SELECT  *
#               FROM positions
#               WHERE regatta = '{}'
#               and race = '{}'
#               and comp_id = {}
#               and leg_nr = 1""".format(regName ,raceName, comp_id)
#             track = pd.read_sql_query(sql, con = engine, chunksize=None)
        if track.empty:
            print('No track found {} {} {}'.format(regName, raceName, comp_id)))
            break

        stats = [str(x) for x in trackStatistics(track)]
        cursor.execute("""
        UPDATE comp_leg
        SET    comp_leg.avg_side = {}
               ,comp_leg.most_left = {}
               ,comp_leg.most_right = {}
        WHERE
        regatta = '{}'
          and race = '{}'
          and comp_id = {}
          and leg_nr = 1
          """.format(stats[0], stats[1], stats[2],regName ,raceName , comp_id)
                      )
        cursor.commit()
# Out:
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x08CD456E6C244EFBA25DD2E4D6E97DC5 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x111FB028073548EE936B74B7EEEF6C1C Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x12BCFE7E54694FF990DEB0447ED067C6 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x1839EB9AAC884E30BAE46567C2405D52 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x3411A94E0C214C61B7C40165B359D41D Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x36C6F6369AF7448BA2677C707805B846 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x426D46C991D240338903232EC7C26A40 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x4BAA901692EB4610A5965C6C0395EFF1 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x4CC029E8BF484C998EA7002B291B9341 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x5B1002861BB94AEE80003F17B317F412 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x5CCA8EFB546A42E08AC907B1C7685220 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x6251F54C007544978A907210245E639C Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0
Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x426D46C991D240338903232EC7C26A40 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x5B1002861BB94AEE80003F17B317F412 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x5CCA8EFB546A42E08AC907B1C7685220 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xAC7AC3713E8347FE920D223D21BFBF01 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xE12C7DFF0E4D4A1583365F935A45C770 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xE7D5E2C36316483CBC052B25E1EFBA9B Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xED4885D953264D14A53FB0EDCA188220 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x08CD456E6C244EFBA25DD2E4D6E97DC5 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x111FB028073548EE936B74B7EEEF6C1C Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x12BCFE7E54694FF990DEB0447ED067C6 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x1839EB9AAC884E30BAE46567C2405D52 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x3411A94E0C214C61B7C40165B359D41D Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x36C6F6369AF7448BA2677C707805B846 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x426D46C991D240338903232EC7C26A40 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x4BAA901692EB4610A5965C6C0395EFF1 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x4CC029E8BF484C998EA7002B291B9341 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x5B1002861BB94AEE80003F17B317F412 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x5CCA8EFB546A42E08AC907B1C7685220 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x6251F54C007544978A907210245E639C Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x8791905991364BB19F3EC0D3331F27D0 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x923B1088F17C48698A0B3F66DA82F177 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xAC7AC3713E8347FE920D223D21BFBF01 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xD7A73B57F2CE4F748DD993CB891DC314 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xDE0E306C5BA541AC8296CCC027918966 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xE12C7DFF0E4D4A1583365F935A45C770 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xE7D5E2C36316483CBC052B25E1EFBA9B Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0xED4885D953264D14A53FB0EDCA188220 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x08CD456E6C244EFBA25DD2E4D6E97DC5 Side already determined
# Tokyo 2019 - RS:X Women R1 (RS:X Women) 0x111FB028073548EE936B74B7EEEF6C1C Side already determined
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# OperationalError: ('08S01', '[08S01] [Microsoft][ODBC Driver 17 for SQL Server]TCP Provider: Een verbindingspoging is mislukt omdat de verbonden party niet correct heeft geantwoord na een bepaalde tijd, of de gemaakte verbinding is mislukt omdat de verbonden host niet heeft geantwoord.\r\n (10060) (SQLExecDirectW); [08S01] [Microsoft][ODBC Driver 17 for SQL Server]Communication link failure (10060)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-57-7cf941415202> in <module>
#      22           and comp_id = {}
#      23           and leg_nr = 1""".format(regName , raceName , comp_id)
# ---> 24         comp_leg = pd.read_sql_query(sql, con = engine, chunksize=None)
#      25
#      26         if not (comp_leg.avg_side.values[0] is None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2177
#    2178         connection = self._contextual_connect(close_with_result=True)
# -> 2179         return connection.execute(statement, *multiparams, **params)
#    2180
#    2181     def scalar(self, statement, *multiparams, **params):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1247                 if not evt_handled:
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#    1251         except BaseException as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     578
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#     582     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (pyodbc.OperationalError) ('08S01', '[08S01] [Microsoft][ODBC Driver 17 for SQL Server]TCP Provider: Een verbindingspoging is mislukt omdat de verbonden party niet correct heeft geantwoord na een bepaalde tijd, of de gemaakte verbinding is mislukt omdat de verbonden host niet heeft geantwoord.\r\n (10060) (SQLExecDirectW); [08S01] [Microsoft][ODBC Driver 17 for SQL Server]Communication link failure (10060)')
# [SQL: SELECT  TOP (1) *
#           FROM comp_leg
#           WHERE regatta = 'Tokyo 2019 - RS:X Women'
#           and race = 'R1 (RS:X Women)'
#           and comp_id = 0x12BCFE7E54694FF990DEB0447ED067C6
#           and leg_nr = 1]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
cnxn.commit()

# %% [markdown]
# ## Determining Course Area

# %%
sql = """SELECT  *
  FROM course_areas"""
areas = pd.read_sql_query(sql, con = engine)

areas['equid'] = areas.apply(lambda x:  coordinatesToEquiv(x, centre = False), axis =  1)


for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        regName = regatta.regatta
        sql = """SELECT  *
          FROM races
          WHERE races.regatta = '{}'""".format(regName)
        df = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True, params=None, parse_dates=None, chunksize=None)

        for ind, race in df.iterrows():
            print('determining racearea of {} {}'.format(regName,race['race'])
                  , end = ' ')
            value = str(getArea(race, areas))
            if value == "-1":
                continue
            print(value)
            cursor.execute("""UPDATE races
                            SET races.course_area_id = {}
                            WHERE regatta = '{}'
                                AND race = '{}'
                            """.format(value, regName, race['race']))
            cursor.commit()

# %% [markdown]
# ## Number of competitors per race and their relative rank

# %%
cursor.execute("""
                UPDATE
                    races
                SET
                    races.nr_competitors = temp_table.nr_competitors
                FROM
                    (SELECT race_comp.regatta, race_comp.race, count(rank) as nr_competitors
                                              FROM race_comp 
                                              GROUP by regatta, race) AS temp_table
                    INNER JOIN races on temp_table.regatta = races.regatta
                            and temp_table.race = races.race
            """)
cursor.commit()

# %%
cursor.execute("""
                UPDATE
                    comp_leg
                SET
                    comp_leg.rel_rank = temp_table.rel_rank
                FROM
                    (SELECT comp_leg.regatta, comp_leg.race, comp_leg.comp_id
                           ,comp_leg.competitor_rank
                           , comp_leg.competitor_rank/convert(decimal(4,2), races.nr_competitors) as rel_rank
                        FROM comp_leg INNER JOIN races
                            ON comp_leg.regatta = races.regatta 
                            and comp_leg.race = races.race
                        )
                        AS temp_table INNER JOIN comp_leg
                            ON comp_leg.regatta = temp_table.regatta 
                                 and comp_leg.race = temp_table.race
                                 and comp_leg.comp_id = temp_table.comp_id

                """)
cursor.commit()

# %% [markdown]
# ## Categorize Sailing Style per Race

# %%
regName = 'HWCS 2020 Round 1 - 470 Men'
sql = """SELECT  *
  FROM legs
  WHERE regatta = '{}'
  and leg_nr = 1""".format(regName)
df = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True, params=None, parse_dates=None, chunksize=None)
race = df.loc[4,:]
print(race)
sql = """SELECT  *
  FROM sailing_style"""
styles = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True, params=None, parse_dates=None, chunksize=None)
style = styles.loc[1,:]
style

# %%
race

# %%
for serv in eventSelection:
    for indx, regatta in serv['regattas'].iterrows():
        print('determining sailing types of {}'.format(regName)
        regName = regatta.regatta
        sql = """SELECT  *
          FROM legs
          WHERE legs.regatta = '{}'
          and leg_nr = 1""".format(regName)
        df = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True, params=None, parse_dates=None, chunksize=None)
        
        for ind, race in df.iterrows():
                  , end = ' ')
            print(race.correlation_tacks)
            if isnan(race.correlation_tacks):
                continue
            value = sailing_style(race, styles)
            print(value)
            cursor.execute("""UPDATE races
                            SET races.sail_style_id = {}
                            WHERE regatta = '{}'
                                AND race = '{}'
                            """.format(value, regName, race['race']))
            cursor.commit()

# %%
df

# %% [markdown]
# ## Positions Start Line

# %%
## get from new positions

# %%
for indx, row in eventSelection.iterrows():    
    regName = row.regatta
    raceName = row.race
    ## Start time
    sql = """SELECT  *
      FROM races
      WHERE regatta = '{}'
      and race = '{}'""".format(regName, raceName)
    race = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True,
                             params=None, parse_dates=None, chunksize=None)

    st = race['startOfRace-ms'].values[0] ## start time
    if st is None:
        print('\t No start time found for {} {}'.format(regName, raceName))
        continue


    print('Updating Startline', end = '\r')


    ## position buoys
    sql = """SELECT  *
      FROM courses
      WHERE regatta = '{}'
      and race = '{}'
      and mark_nr = 0""".format(regName, raceName)
    start = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True,
                              params=None, parse_dates=None, chunksize=None)

    id_l = start['controlPoint.left.id'].values[0]  #RC
    id_r = start['controlPoint.right.id'].values[0] #Pin

    sql = """SELECT  *
      FROM marks_positions
      WHERE regatta = '{}'
      and race = '{}'
      and (id = {} or id = {})
      and [timepoint-ms] <= {}+3000
      and [timepoint-ms] >= {}-3000""".format(regName, raceName, idToText(id_l), idToText(id_r), st,st)
    st_line = pd.read_sql_query(sql, con = engine)
    #select one timepoint
    if st_line.empty:
        print("\tNo startline available for {} {}".format(regName, raceName))
        continue
    mask = st_line[['id', 'timepoint-ms']].groupby('id').idxmin()['timepoint-ms']
    st_line = st_line.loc[mask].set_index('id')            
    
    if len(st_line)<2:
        print('Startline not complete for {} {}'.format(regName, raceName))
        continue
    rc = st_line.loc[id_l,:]
    pin = st_line.loc[id_r,:]
    st_bearing = bearing(rc,pin)        
        
    ## windmeasurements at start
    skip_wind = 0
    sql = """SELECT * FROM windsources
                    WHERE regatta = '{}'
                        AND race = '{}'
                        AND typeName = 'EXPEDITION'""".format(regName, raceName)
    windsources = pd.read_sql_query(sql, con = engine)
    rc_windsource = windsources.loc[windsources.rc == 1]
    
    if rc_windsource.empty:
         ## wind measurement at RC
        print('Get windsources', end = '\r')
        sql = """SELECT  *
            FROM wind
            WHERE regatta = '{}'
            and race = '{}'
            and [timepoint-ms] <= {}+3000
            and [timepoint-ms] >= {}-3000
            """.format(regName, raceName, st, st)
        wind = pd.read_sql_query(sql, con = engine)
        wind = wind.loc[wind.windSource == 'EXPEDITION']
        if wind.empty:
            print('No wind measurements available for {} {}'.format(regName, raceName))
            skip_wind = 1
        
        else:
            print('Determine closest ws', end = '\r')
            rc = st_line.loc[id_l,:]
            dist = wind[['lat-deg', 'lng-deg']].apply(lambda x: np.linalg.norm([x['lat-deg']- rc['lat-deg'],
                                                                                x['lng-deg']- rc['lng-deg']]),
                                               axis = 1)

            source = wind.loc[dist.idxmin()] 
            ## Update windsources to highlight this source to be at the rc
            sql = """UPDATE windsources
                            SET windsources.rc = 1
                            WHERE regatta = '{}'
                                AND race = '{}'
                                AND typeName = 'EXPEDITION'
                                AND id = '{}'
                            """.format(regName, raceName, source.windSource_id )
            cursor.execute(sql)
            cursor.commit()

    else:
        print('Wind at rc is already determined', end = '\r')
        # So the closest wind source is already known
        sql = """SELECT  *
            FROM wind
            WHERE regatta = '{}'
            and race = '{}'
            and windSource = 'EXPEDITION'
            and windSource_id = '{}'
            """.format(regName, raceName, rc_windsource.id.values[0])
        wind = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True, params=None,
                                 parse_dates=None, chunksize=None)
        source = wind.loc[0]
    
    if not skip_wind:
        wind_msr = wind.loc[(wind.windSource_id == source.windSource_id) & (wind['timepoint-ms'] == st)].reset_index()
                    ### check if there always exists one
        if wind_msr.empty:
            wind_msr = wind.loc[(wind.windSource_id == source.windSource_id)].reset_index()
            wind_time = wind_msr['timepoint-ms'].apply(lambda x: abs(x - st)).idxmin()
            wind_msr = wind_msr.loc[wind_time]

        ## determine startline stats
        wind_dir = wind_msr.squeeze()['dampenedTrueBearing-deg']
        dir_diff = wind_dir - (st_bearing - 90) 
        dir_diff = ((dir_diff+ 180)%360) - 180 ## denk na over modulo rekenen, zodat alles tussen -40 + 40 komt

        if dir_diff <-90:
            dir_diff +=180
        if dir_diff >90:
            dir_diff -= 180
        if dir_diff<0:
            side = 'Left'
        else:
            side = 'Right'
#             plt.plot(rc['lng-deg'], rc['lat-deg'], 'r.')
#             plt.plot(pin['lng-deg'], pin['lat-deg'], 'b.')
#             plt.show()
#             print('st_bearing = {}\t perpendicular to st = {}\t windbearing = {}\t calculated angle = {}'.format(st_bearing,
#                                                                                                                 (st_bearing - 90), 
#                                                                                                                 wind_msr.squeeze()['trueBearing-deg'],
#                                                                                                                 dir_diff))
        ## update races table
        sql = """UPDATE races
                        SET races.stl_bearing_diff_wind = {}
                        , races.stl_fav_side = '{}'
                        , races.start_wind_dir = {}
                        , races.stl_bearing = {}
                        WHERE regatta = '{}'
                            AND race = '{}'
                        """.format(dir_diff, side, wind_dir, st_bearing, regName, raceName)
        cursor.execute(sql)
        cursor.commit()

    print('Updating Competitors at Start    ', end = '\r')
    # check whether competitors are already updated
    sql =""" SELECT * from race_comp
                    WHERE regatta = '{}'
                        AND race = '{}'
                        AND pos_startline_abs_x IS NOT NULL                               

                    """.format(regName,
                               raceName)
    df = pd.read_sql(sql, con = engine)
    if not df.empty:
        print('competitor start locations already known for {} {}'.format(regName, raceName))
        continue



    ## positions competitors at start
    sql = """select p.*
            from positions p
            join (select regatta, race, comp_id, min(timepoint_ms) as t
                  from positions
                  group by regatta, race, comp_id) p2
                on p.regatta = p2.regatta and p.race = p2.race and p.comp_id = p2.comp_id 
                and p.timepoint_ms = p2.t
            Inner join comp_leg as cl on 
                    p.regatta = cl.regatta and p.race = cl.race and p.comp_id = cl.comp_id 
                    and p.leg_nr = cl.leg_nr
            where 
            p.regatta = '{}'
            and p.race = '{}'
            and cl.competitor_started = 1 and cl.leg_nr = 1
    """.format(regName, raceName)
    comp = pd.read_sql_query(sql, con = engine, index_col=None, coerce_float=True, params=None,
                             parse_dates=None, chunksize=None)
    if comp.empty:
        print('WARNING: No positions found for competitors')

    X = startline(comp, pin, rc)
    X_x =  np.asarray(X)[0]
    X_y = np.asarray(X)[1]
    plt.plot(X_x, X_y, '.')
    plt.axis('equal')
    plt.show()
    comp['pos_startline_abs_x'] = X_x
    comp['pos_startline_abs_y'] = X_y
    rel_order = X_x.argsort().argsort()/(len(X_x)-1)
    comp['pos_startline_rel'] = rel_order

    ## Update race_comp
    for idx, competitor in comp.iterrows():
        sql = """UPDATE race_comp
                    SET race_comp.pos_startline_abs_x = {}
                    , race_comp.pos_startline_abs_y = {}
                    , race_comp.pos_startline_rel = {}
                    WHERE regatta = '{}'
                        AND race = '{}'
                        AND comp_id = {}
                    """.format(competitor.pos_startline_abs_x,
                               competitor.pos_startline_abs_y,
                               competitor.pos_startline_rel,
                               regName,
                               raceName,
                              idToText(competitor.comp_id))
        cursor.execute(sql)
        cursor.commit()

    print('Succesfully updated startline for {} {}'.format(regName,raceName))

# %%
# Out:
# Empty DataFrame
# Columns: [regatta, race, windSource, windSource_id, trueBearing-deg, speed-kts, speed-m/s, timepoint-ms, dampenedTrueBearing-deg, dampenedSpeed-kts, dampenedSpeed-m/s, lat-deg, lng-deg]
# Index: []

# %% [markdown]
# ## positions_view

# %%
CREATE VIEW positions_view
WITH SCHEMABINDING
AS 
SELECT
    r.regatta,
    rc.race,
    l.leg_nr,
    c.comp_id,
    timepoint_ms,
    [lat-deg],
	[lng-deg]
	,[speed-kts]
	,[truebearing-deg]
FROM
    dbo.positions p
INNER JOIN dbo.competitors c
    ON c.comp_id = p.comp_id
	 and c.regatta = p.regatta
INNER JOIN dbo.legs l
	ON l.regatta = p.regatta
	 and l.race = p.race
	 and l.leg_nr = p.leg_nr
INNER JOIN dbo.races rc 
    ON rc.regatta = p.regatta
	 and rc.race = p.race
INNER JOIN dbo.regattas r
	ON r.regatta = p.regatta
WHERE l.leg_nr = 1
 and p.timepoint_ms % 20000 = 0
	 ;
        

CREATE NONCLUSTERED INDEX 
    idx_regatta
ON dbo.positions_view(regatta);

# %% [markdown]
# ## Calculate Correlations

# %%
sql = """
SELECT * from races"""
sql = """
SELECT * from legs 
where pos_startline_abs_x IS NULL and
correlation_side is not null
and leg_nr = 1

"""


eventSelection = pd.read_sql(sql, con= engine)
eventSelection
# Out:
#                              regatta                    race  leg_nr  \
# 0            Tokyo 2019 - RS:X Women         R1 (RS:X Women)       1
# 1            Tokyo 2019 - RS:X Women        R10 (RS:X Women)       1
# 2            Tokyo 2019 - RS:X Women        R11 (RS:X Women)       1
# 3            Tokyo 2019 - RS:X Women  R12 Medal (RS:X Women)       1
# 4            Tokyo 2019 - RS:X Women         R2 (RS:X Women)       1
# 5            Tokyo 2019 - RS:X Women         R3 (RS:X Women)       1
# 6            Tokyo 2019 - RS:X Women         R4 (RS:X Women)       1
# 7            Tokyo 2019 - RS:X Women         R5 (RS:X Women)       1
# 8            Tokyo 2019 - RS:X Women         R6 (RS:X Women)       1
# 9            Tokyo 2019 - RS:X Women         R7 (RS:X Women)       1
# 10           Tokyo 2019 - RS:X Women         R8 (RS:X Women)       1
# 14     b'\x1eH1LK\xc5@\xcf\xa7\x99t\x90\xab\xc7\xc8#'   T - 1   T - Start
# 15  b'\x0c\xc4u\xd2\xb5\xc6FE\x9a\x96\xe8F\xae\xa1...     W-1   W - Start
# 16  b'\xe5+\x88\xd5\xf0\xfcB\xa9\x86\xa0\x8dc;\xaa...     W-1   W - Start
# 17  b'\xec\x14\x84H4\\G\xbc\xba\x04\x0c\xce\xba\x9...     W-1   W - Start
# 18  b'e\x15\x8d\xbd\xed\xabH\x10\xbf\xef\x18\xbd\x...     W-1   W - Start
# 19           b'\xeb3\xb3tM1I\xae\x90FQ]\x82\x9f\x8aV'     W-1   W - Start
# 20     b'\xb5\x8e\x1a\x8e@\x1bFu\x99\xf4r\xb93V\x8f>'     W-1   W - Start
# 21  b'@\x12\xd3\x99HNO\xa0\xbc\xd6\xc9\x9d\r\xab\x...     W-1   W - Start
# 22     b'Vl\x92\x01gZI\x1f\xba\xd1N\xbfU\xb6\x80\xbf'     W-1   W - Start
# 23     b'f\xbf\xc8\xc7V\xb4Fg\x8f\x88\xf2A\x1f,\x8d:'     W-1   W - Start
# 24     b'\x15T\xef\xbb^XB]\x9f/\xa8\x12\x1f)\xc1\xe3'     W-1   W - Start
# 25  b'\xf4c\x81\xb4\xeb\xecI\xa1\x8e\x86\x1e\xaa\x...     W-1   W - Start
# 26     b'\x91Y\xf4\x88`>D\xab\x9bw\x0c3\xceY\xd3\xf3'     Z-1   Z - Start
# 27        b'\x85\xaaH\xe2\xef\x1fF}\x9eY\x90e\x01"QN'     Y-1   Y - Start
# 28        b'\xa2&\xb58\x06kFk\x9c\xc1bdL\xf5\xfe\xe7'   T - 1   T - Start
# 29  b'\x83\xfa\xac\x88,\xaaH\xc0\xaf\x1f:\x8f&\xed...    None       Start
# 30     b'\x8f\xfc\x8d%\xcd\xc7@<\xb6I^\x8b7\xe5Y\xae'    None       Start
#
#     upOrDownwindLeg  leg_nr_from_finish distance  correlation_tacks  \
# 0              True                   5     None            -0.2586
# 1              True                   6     None             0.2426
# 2              True                   6     None             0.1065
# 3              True                   5     None             0.7977
# 4              True                   5     None             0.5290
# 5              True                   5     None             0.1621
# 6             False                   5     None             0.0264
# 7              True                   5     None             0.1503
# 8              True                   6     None             0.1253
# 9              True                   6     None             0.4822
# 10             True                   6     None            -0.2927
# 11             True                   6     None             0.3496
# 12             True                   6     None             0.5081
# 13             True                   5     None             0.7240
# 14             True                   7     None             0.4521
# 15             True                   5     None             0.5771
# 16             True                   6     None             0.4972
# 17             True                   5     None            -0.3137
# 18             True                   5     None             0.6768
# 19             True                   5     None             0.1628
# 20             True                   5     None             0.3095
# 21             True                   6     None             0.6757
# 22             True                   6     None             0.2840
# 23            False                   6     None            -0.3926
# 24             True                   6     None             0.2664
# 25             True                   6     None             0.4606
# 26             True                   5     None             0.3544
# 27             True                   9     None            -0.0579
# 28             True                   6     None             0.4759
# 29             True                   6     None             0.3512
# 30             True                   6     None             0.6881
#
#     correlation_side  correlation_avgSOG  correlation_traveledDistance  \
# 30              None                       None                       None

# %%
## not yet right for other legs then 1, because avg side needs to be calculated first

for idx, row in eventSelection.iterrows():
    stop = 0
    regName = row.regatta
    raceName = row.race
    sql = """
    SELECT * from legs
    where leg_nr = 1
        and regatta = '{}'
        and race = '{}'
        """.format(regName, raceName)

    legs = pd.read_sql(sql, engine)
    for index, row in legs.iterrows():
        
        sql = """
        SELECT comp_leg.*
                , race_comp.pos_startline_abs_x
                , race_comp.pos_startline_abs_y
                ,race_comp.pos_startline_rel 
                    from comp_leg INNER JOIN race_comp
        ON race_comp.regatta = comp_leg.regatta
            and race_comp.race = comp_leg.race
            and race_comp.comp_id = comp_leg.comp_id          
        WHERE comp_leg.regatta = '{}'
        and comp_leg.race = '{}'
        and comp_leg.leg_nr = {}
        """.format( regName,
                    raceName,
                    row['leg_nr'])

        df = pd.read_sql(sql, engine)
        correlations = df.corr()
        try:
            corrs = correlations.rel_rank.replace(np.nan, "NULL", regex=True)  ### replace NaN's by NULL so they can be updated in the sql df

            corrs_side = correlations.avg_side
        except AttributeError as a:
            print('Attribute Error: {} for {} {}'.format(a, regName, raceName))
        try:
            cursor.execute("""
            UPDATE legs
            SET    legs.correlation_tacks = {}
                  ,legs.correlation_side = {}
                  ,legs.correlation_avgSOG = {}
                  ,legs.correlation_traveledDistance = {}
                  ,legs.correlation_jibes = {}
                  ,legs.pos_startline_abs_x = {}
                  ,legs.pos_startline_abs_y = {}
                  ,legs.pos_startline_rel = {}
                  ,legs.cor_side_pos_startline_abs = {}
                  ,legs.cor_side_pos_startline_rel = {}
            WHERE
            regatta = '{}'
            and race = '{}'
            and leg_nr = '{}'
              """.format(corrs['competitor_tacks'],
                         corrs['avg_side'],
                         corrs['competitor_averageSOG-kts'],
                         corrs['competitor_distanceTraveled-m'],
                         corrs['competitor_jibes'], 
                         corrs['pos_startline_abs_x'], 
                         corrs['pos_startline_abs_y'], 
                         corrs['pos_startline_rel'],  
                         corrs_side.pos_startline_abs_x,
                         corrs_side.pos_startline_rel,
                         regName,
                         raceName,
                         row['leg_nr']))        
        except KeyError as e:
            print('Key Error: {} for {} {}'.format(e, regName, raceName))
            stop = 1
        cursor.commit()
        print('{} {} Succesfull'.format(regName, raceName))
# Out:
# Tokyo 2019 - RS:X Women R1 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R10 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R11 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R12 Medal (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R2 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R3 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R4 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R5 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R6 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R7 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R8 (RS:X Women) Succesfull
# Tokyo 2019 - RS:X Women R9 (RS:X Women) Succesfull
# Key Error: 'pos_startline_abs_x' for Toyko 2019 - 470 Women R3 (470 Women)
# Toyko 2019 - 470 Women R3 (470 Women) Succesfull
# Key Error: 'pos_startline_abs_x' for Tokyo 2019 - Laser Radial R7 (Laser Radial)
# Tokyo 2019 - Laser Radial R7 (Laser Radial) Succesfull
# Key Error: 'pos_startline_abs_x' for Tokyo 2019 - 470 Men R8 (470 Men)
# Tokyo 2019 - 470 Men R8 (470 Men) Succesfull
# Tokyo 2019 - RS:X Men R1 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R10 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R11 Medal (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R2 (RS:X men) Succesfull
# Tokyo 2019 - RS:X Men R3 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R4 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R5 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R6 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R7 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R8 (RS:X Men) Succesfull
# Tokyo 2019 - RS:X Men R9 (RS:X Men) Succesfull
# Key Error: 'pos_startline_abs_x' for Tokyo 2019 - Finn R8 (Finn)
# Tokyo 2019 - Finn R8 (Finn) Succesfull
# Key Error: 'pos_startline_abs_x' for Tokyo 2019 - Nacra 17 R6 (Nacra 17)
# Tokyo 2019 - Nacra 17 R6 (Nacra 17) Succesfull
# HWCS 2020 Round 1 - 470 Men R1 (470 Men) Succesfull
# Key Error: 'pos_startline_abs_x' for WCS 2019 Enoshima - Laser Radial R6
# WCS 2019 Enoshima - Laser Radial R6 Succesfull
# Key Error: 'pos_startline_abs_x' for WCS 2019 Enoshima - Laser Radial R7
# WCS 2019 Enoshima - Laser Radial R7 Succesfull

# %%
sql = """
SELECT * from legs 
where pos_startline_abs_x IS NULL and
correlation_side is not null
and leg_nr = 1

"""
df = pd.read_sql(sql, con = engine)
df
# Out:
#                              regatta                    race  leg_nr  \
# 0            Tokyo 2019 - RS:X Women         R1 (RS:X Women)       1
# 1            Tokyo 2019 - RS:X Women        R10 (RS:X Women)       1
# 2            Tokyo 2019 - RS:X Women        R11 (RS:X Women)       1
# 3            Tokyo 2019 - RS:X Women  R12 Medal (RS:X Women)       1
# 4            Tokyo 2019 - RS:X Women         R2 (RS:X Women)       1
# 5            Tokyo 2019 - RS:X Women         R3 (RS:X Women)       1
# 6            Tokyo 2019 - RS:X Women         R4 (RS:X Women)       1
# 7            Tokyo 2019 - RS:X Women         R5 (RS:X Women)       1
# 8            Tokyo 2019 - RS:X Women         R6 (RS:X Women)       1
# 9            Tokyo 2019 - RS:X Women         R7 (RS:X Women)       1
# 10           Tokyo 2019 - RS:X Women         R8 (RS:X Women)       1
# 11           Tokyo 2019 - RS:X Women         R9 (RS:X Women)       1
# 12            Toyko 2019 - 470 Women          R3 (470 Women)       1
# 13         Tokyo 2019 - Laser Radial       R7 (Laser Radial)       1
# 14              Tokyo 2019 - 470 Men            R8 (470 Men)       1
# 15             Tokyo 2019 - RS:X Men           R1 (RS:X Men)       1
# 16             Tokyo 2019 - RS:X Men          R10 (RS:X Men)       1
# 17             Tokyo 2019 - RS:X Men    R11 Medal (RS:X Men)       1
# 18             Tokyo 2019 - RS:X Men           R2 (RS:X men)       1
# 19             Tokyo 2019 - RS:X Men           R3 (RS:X Men)       1
# 20             Tokyo 2019 - RS:X Men           R4 (RS:X Men)       1
# 21             Tokyo 2019 - RS:X Men           R5 (RS:X Men)       1
# 21  b'@\x12\xd3\x99HNO\xa0\xbc\xd6\xc9\x9d\r\xab\x...     W-1   W - Start
# 22     b'Vl\x92\x01gZI\x1f\xba\xd1N\xbfU\xb6\x80\xbf'     W-1   W - Start
# 23     b'f\xbf\xc8\xc7V\xb4Fg\x8f\x88\xf2A\x1f,\x8d:'     W-1   W - Start
# 24     b'\x15T\xef\xbb^XB]\x9f/\xa8\x12\x1f)\xc1\xe3'     W-1   W - Start
# 25  b'\xf4c\x81\xb4\xeb\xecI\xa1\x8e\x86\x1e\xaa\x...     W-1   W - Start
# 26     b'\x91Y\xf4\x88`>D\xab\x9bw\x0c3\xceY\xd3\xf3'     Z-1   Z - Start
# 27        b'\x85\xaaH\xe2\xef\x1fF}\x9eY\x90e\x01"QN'     Y-1   Y - Start
# 28        b'\xa2&\xb58\x06kFk\x9c\xc1bdL\xf5\xfe\xe7'   T - 1   T - Start
# 29  b'\x83\xfa\xac\x88,\xaaH\xc0\xaf\x1f:\x8f&\xed...    None       Start
# 30     b'\x8f\xfc\x8d%\xcd\xc7@<\xb6I^\x8b7\xe5Y\xae'    None       Start
#
#     upOrDownwindLeg  leg_nr_from_finish distance  correlation_tacks  \
# 0              True                   5     None            -0.2586
# 1              True                   6     None             0.2426
# 2              True                   6     None             0.1065
# 3              True                   5     None             0.7977
# 4              True                   5     None             0.5290
# 5              True                   5     None             0.1621
# 6             False                   5     None             0.0264
# 7              True                   5     None             0.1503
# 8              True                   6     None             0.1253
# 9              True                   6     None             0.4822
# 10             True                   6     None            -0.2927
# 11             True                   6     None             0.3496
# 12             True                   6     None             0.5081
# 13             True                   5     None             0.7240
# 14             True                   7     None             0.4521
# 15             True                   5     None             0.5771
# 16             True                   6     None             0.4972
# 17             True                   5     None            -0.3137
# 18             True                   5     None             0.6768
# 19             True                   5     None             0.1628
# 20             True                   5     None             0.3095
# 21             True                   6     None             0.6757
# 22             True                   6     None             0.2840
# 23            False                   6     None            -0.3926
# 24             True                   6     None             0.2664
# 25             True                   6     None             0.4606
# 26             True                   5     None             0.3544
# 27             True                   9     None            -0.0579
# 28             True                   6     None             0.4759
# 29             True                   6     None             0.3512
# 30             True                   6     None             0.6881
#
#     correlation_side  correlation_avgSOG  correlation_traveledDistance  \
# 0             0.3705             -0.2870                        0.7203
# 1            -0.1444             -0.0804                        0.6309
# 2             0.7157             -0.2676                        0.5755
# 3            -0.6687             -0.8099                       -0.3754
# 4             0.2411             -0.3134                        0.6899
# 5             0.0339             -0.3196                        0.8389
# 6            -0.4246             -0.8082                        0.5028
# 7            -0.7553             -0.2778                        0.4595
# 8             0.0114             -0.4016                        0.0433
# 9            -0.4148             -0.6537                        0.1701
# 10           -0.0836             -0.6653                        0.4041
# 11            0.5709             -0.5142                        0.5117
# 12           -0.2149              0.0140                        0.8199
# 13           -0.4561             -0.4274                        0.7117
# 14            0.2347             -0.3939                        0.4708
# 15           -0.7315             -0.8084                        0.8809
# 16            0.5411             -0.0009                        0.8361
# 17            0.6011             -0.7550                        0.4997
# 18           -0.7477             -0.8496                        0.4880
# 19           -0.1282             -0.1095                        0.9224
# 20           -0.4365             -0.7956                        0.6521
# 21           -0.6491             -0.5574                        0.7655
# 22            0.2105             -0.6364                        0.4214
# 23            0.9258             -0.5379                        0.6914
# 24           -0.3811             -0.4355                        0.6321
# 25           -0.1764             -0.6440                       -0.1748
# 26            0.6338             -0.4318                        0.4265
# 27            0.0749             -0.2292                        0.6988
# 28            0.0800             -0.6171                        0.3759
# 29            0.0879             -0.5070                        0.7922
# 30           -0.9082             -0.7509                        0.7652
#
#     correlation_jibes pos_startline_abs_x pos_startline_abs_y  \
# 0                 NaN                None                None
# 1              0.1636                None                None
# 2                 NaN                None                None
# 3                 NaN                None                None
# 4                 NaN                None                None
# 5                 NaN                None                None
# 6             -0.0871                None                None
# 7                 NaN                None                None
# 8                 NaN                None                None
# 9                 NaN                None                None
# 10                NaN                None                None
# 11                NaN                None                None
# 12             0.3780                None                None
# 13             0.5436                None                None
# 14                NaN                None                None
# 15             0.3024                None                None
# 16                NaN                None                None
# 17             0.5222                None                None
# 18             0.3620                None                None
# 19                NaN                None                None
# 20            -0.0421                None                None
# 21             0.0942                None                None
# 22             0.3438                None                None
# 23             0.3527                None                None
# 24            -0.2594                None                None
# 25             0.0356                None                None
# 26                NaN                None                None
# 27            -0.1393                None                None
# 28                NaN                None                None
# 29                NaN                None                None
# 30            -0.0658                None                None
#
#    pos_startline_rel cor_side_pos_startline_abs cor_side_pos_startline_rel
# 0               None                       None                       None
# 1               None                       None                       None
# 2               None                       None                       None
# 3               None                       None                       None
# 4               None                       None                       None
# 5               None                       None                       None
# 6               None                       None                       None
# 7               None                       None                       None
# 8               None                       None                       None
# 9               None                       None                       None
# 10              None                       None                       None
# 11              None                       None                       None
# 12              None                       None                       None
# 13              None                       None                       None
# 14              None                       None                       None
# 15              None                       None                       None
# 16              None                       None                       None
# 17              None                       None                       None
# 18              None                       None                       None
# 19              None                       None                       None
# 20              None                       None                       None
# 21              None                       None                       None
# 22              None                       None                       None
# 23              None                       None                       None
# 24              None                       None                       None
# 25              None                       None                       None
# 26              None                       None                       None
# 27              None                       None                       None
# 28              None                       None                       None
# 29              None                       None                       None
# 30              None                       None                       None

# %% [markdown]
# # Extra

# %% [markdown]
# ## Usefull other queries

# %%
cursor.execute("""

USE nerinedatabase;
EXEC sp_spaceused;
""")

# %%
cursor.execute("""
DROP INDEX idx ON positions;
CREATE UNIQUE CLUSTERED INDEX idx ON positions (regatta, race, comp_id, timepoint_ms ASC);

""")

# %%
# info over indeces
EXEC sp_helpindex '[[[SCHEMA-NAME.TABLE-NAME]]]'
GO

## snelle manier om aantal rijen in tabel te krijgen
DECLARE @TableName sysname
SET @TableName = 'positions'
 
SELECT OBJECT_NAME(object_id), SUM(row_count) AS rows
FROM sys.dm_db_partition_stats
WHERE object_id = OBJECT_ID(@TableName)
AND index_id < 2
GROUP BY OBJECT_NAME(object_id);
